# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
from ufit.lab import *
from ufit.plotting import mapping
# %matplotlib inline

# %%
set_datatemplate('070%03d')
data = read_numors('235-241', 0)

mapping("QL", "EN", data, log = True, dots = False)
plt.title('Energy scan along c in M-point at 10T')
plt.xlabel("(1/3, 1/3, L) (r.l.u.)")
plt.ylabel("E(meV)")
show()
