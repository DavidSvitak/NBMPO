# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
from ufit.lab import *
from ufit.plotting import mapping
# %matplotlib inline

# %%
set_datatemplate('0700%2d')
data = read_data(75)
data.plot()
show()
