# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.backends.backend_pdf import PdfPages
from ufit.lab import *
from ufit.plotting import mapping
#%matplotlib inline

# %%
set_datatemplate('070%03d')
data = read_numors('228-234',0)

mapping("QL", "EN",data, log = True, dots = False)
plt.title('Energy scan along c in K-point at 10T')
plt.xlabel("(1/3, 1/3, L) (r.l.u.)")
plt.ylabel("E(meV)")
plt.show()

# %%
for i in range(228, 235):
    data = read_data(i, "EN", "CNTS")
    data.plot()
plt.xlim((0.1, 0.9))
plt.ylim((0, 500))
show()
