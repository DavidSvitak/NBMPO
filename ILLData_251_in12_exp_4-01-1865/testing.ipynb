# %%
import numpy as np
import matplotlib.pyplot as plt
from ufit import *
from ufit.plotting import mapping
#%matplotlib inline

# %%
set_datatemplate("rawdata/079%03d")

data = read_numors("232-236", 0)
mapping("QH", "EN", data, mode=0, title=f'{data.name}',minmax=[0,2500])
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data_232 = read_data(232, "EN", "CNTS")
data_243 = read_data(243, "EN", "CNTS")
data_237 = read_data(237, "EN", "CNTS")

data_232.plot()
data_237.plot()
data_243.plot()

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data_213 = read_data(213, "EN", "CNTS")
data_237 = read_data(237, "EN", "CNTS")

data_213.plot()
data_237.plot()

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data_229 = read_data(229, "A3", "CNTS")
data_230 = read_data(230, "QL", "CNTS")
data_231 = read_data(231, "QH", "CNTS")
data_229.plot()
_ = plt.figure()
data_230.plot()
_ = plt.figure()
data_231.plot()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
#245, 201, 265
data_201 = read_data(201, "EN", "CNTS")
data_245 = read_data(245, "EN", "CNTS")
data_265 = read_data(265, "EN", "CNTS")

data_201.plot()
data_245.plot()
data_265.plot()

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
#254 232 203
data_203 = read_data(203, "EN", "CNTS")
data_232 = read_data(232, "EN", "CNTS")
data_254 = read_data(254, "EN", "CNTS")

data_203.plot()
data_232.plot()
data_254.plot()

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data = read_numors("276, 278-283", 0)

mapping("QH", "EN", data, mode=0, title=f'{data.name}',minmax=[0,1200])

# %%
for i in range(276, 284):
    data = read_data(i, "EN", "CNTS")
    data.plot()
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data = read_numors("254-271", 0)
data.name = "3.7T"
mapping("QH", "EN", data, mode=0, title=f'{data.name}',minmax=[0,1500])
plt.ylim((0, 0.5))

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data = read_numors("233, 234, 235, 236, 246, 249, 248, 245, 244, 243, 215, 214, 249, 237", 0)
data.name = "2.2T"
mapping("QH", "EN", data, mode=0, title=f'{data.name}',minmax=[0,1500])
plt.ylim((0, 0.5))

plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
data = read_numors("302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314", 0)

mapping("QH", "EN", data, mode=0, title=f'{data.name}',minmax=[0,1500])
plt.title("T=0.6K and H=0.9T")
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...
