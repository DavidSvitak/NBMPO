# %%
from ufit import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv("H_along_c/300mK/092910.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df1 = pd.read_csv("H_along_c/300mK/092917.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df2 = pd.read_csv("H_along_c/300mK/092923.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df3 = pd.read_csv("H_along_c/300mK/092928.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
plt.figure()
plt.plot(df0["QL"], df0["CNTS"], "b-o", label = f"H = {df0['H'][0]} T")
plt.plot(df1["QL"], df1["CNTS"], "r-o", label = f"H = {df1['H'][0]} T")
plt.plot(df2["QL"], df2["CNTS"], "k-o", label = f"H = {df2['H'][0]} T")
plt.plot(df3["QL"], df3["CNTS"], "m-o", label = f"H = {df3['H'][0]} T")
plt.xlabel("(1/3, 1/3, Ql)")
plt.ylabel("Intensity (a. u.)")
plt.legend()
plt.savefig("300mK_all_phases_c.png")
plt.show()

# %%
model0 = Background() + Gauss('peak1', pos=0.85, ampl=350, fwhm=0.05) + Gauss('peak2', pos=1.11, ampl=250, fwhm=0.06)
model1 = Background() + Gauss('peak1', pos=0.85, ampl=250, fwhm=0.05) + Gauss('peak2', pos=1.11, ampl=150, fwhm=0.06)
model2 = Background() + Gauss('peak1', pos=1, ampl=150, fwhm=0.05)
model3 = Background() + Gauss('peak1', pos=0.66, ampl=100, fwhm=0.05) + Gauss('peak2', pos=1.32, ampl=100, fwhm=0.06)

# %%
#dataset = as_data(df["QL"], df["CNTS"], np.sqrt(df["CNTS"]))
models = [model0, model1, model2, model3]
datasets = [df0, df1, df2, df3]
for model, data in zip(models, datasets):
    plt.figure()
    dataset = as_data(data["QL"], data["CNTS"], np.sqrt(data["CNTS"]))
    model.fit(dataset)
    dataset.plot(label = f"H = {data['H'][0]} T")
    model.plot(dataset)
    plt.xlabel("(1/3, 1/3, Ql)")
    plt.ylabel("Intensity (a. u.)")
    plt.title("")
    plt.show()

# %%
df0 = pd.read_csv("H_along_c/1200mK/092981.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df1 = pd.read_csv("H_along_c/1200mK/092985.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df2 = pd.read_csv("H_along_c/1200mK/092986.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df3 = pd.read_csv("H_along_c/1200mK/092989.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df4 = pd.read_csv("H_along_c/1200mK/092995.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)

plt.plot(df0["QL"], df0["CNTS"], "b-o", label = f"H = {df0['H'][0]} T")
plt.plot(df1["QL"], df1["CNTS"], "r-o", label = f"H = {df1['H'][0]} T")
plt.plot(df2["QL"], df2["CNTS"], "k-o", label = f"H = {df2['H'][0]} T")
plt.plot(df3["QL"], df3["CNTS"], "m-o", label = f"H = {df3['H'][0]} T")
plt.plot(df4["QL"], df4["CNTS"], "y-o", label = f"H = {df4['H'][0]} T")

plt.xlabel("(1/3, 1/3, Ql)")
plt.ylabel("Intensity (a. u.)")
plt.legend()
plt.savefig("1200mK_all_phases_c.png")
plt.show()

# %%
model0 = Background() + Gauss('peak1', pos=0.85, ampl=350, fwhm=0.05)
model1 = Background() + Gauss('peak1', pos=0.92, ampl=250, fwhm=0.05) + Gauss('peak2', pos=1.1, ampl=250, fwhm=0.05)
model2 = Background() + Gauss('peak1', pos=1.00, ampl=150, fwhm=0.05)
model3 = Background()

# %%
#dataset = as_data(df["QL"], df["CNTS"], np.sqrt(df["CNTS"]))
models = [model0, model1, model2, model3]
datasets = [df0, df1, df2, df3]
for model, data in zip(models, datasets):
    plt.figure()
    dataset = as_data(data["QL"], data["CNTS"], np.sqrt(data["CNTS"]))
    model.fit(dataset)
    dataset.plot(label = f"H = {int(data['H'][0])} T")
    model.plot(dataset)
    plt.xlabel("(1/3, 1/3, Ql)")
    plt.ylabel("Intensity (a. u.)")
    plt.title("")
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
df0 = pd.read_csv("H_along_ab/300mK/090056.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df1 = pd.read_csv("H_along_ab/300mK/090063.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df2 = pd.read_csv("H_along_ab/300mK/090066.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df3 = pd.read_csv("H_along_ab/300mK/090071.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df4 = pd.read_csv("H_along_ab/300mK/090077.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df5 = pd.read_csv("H_along_ab/300mK/090081.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
plt.figure()
plt.plot(df0["QL"], df0["CNTS"], "b-o", label = f"H = {df0['H'][0]} T")
plt.plot(df1["QL"], df1["CNTS"], "r-o", label = f"H = {df1['H'][0]} T")
plt.plot(df2["QL"], df2["CNTS"], "k-o", label = f"H = {df2['H'][0]} T")
plt.plot(df3["QL"], df3["CNTS"], "m-o", label = f"H = {df3['H'][0]} T")
plt.plot(df4["QL"], df4["CNTS"], "y-o", label = f"H = {df4['H'][0]} T")
plt.plot(df5["QL"], df5["CNTS"], "g-o", label = f"H = {df5['H'][0]} T")

plt.xlabel("(1/3, 1/3, Ql)")
plt.ylabel("Intensity (a. u.)")
plt.legend()
plt.savefig("300mK_all_phases_ab.png")
plt.show()

# %%
model0 = Background() + Gauss('peak1', pos=0.187, ampl=250, fwhm=0.05)
model1 = Background() + Gauss('peak1', pos=0.187, ampl=150, fwhm=0.05) + Gauss('peak2', pos=0.16, ampl=100, fwhm=0.05)
model2 = Background() + Gauss('peak1', pos=0.08, ampl=150, fwhm=0.05) + Gauss('peak2', pos=0.16, ampl=100, fwhm=0.05) #+ Gauss('peak3', pos=1/6, ampl=100, fwhm=0.05) + Gauss('peak4', pos=1/3, ampl=100, fwhm=0.05) + Gauss('peak5', pos=5/12, ampl=100, fwhm=0.05)
model3 = Background() + Gauss('peak1', pos=0.165, ampl=150, fwhm=0.05)
model4 = Background() + Gauss('peak1', pos=0.16, ampl=150, fwhm=0.05) + Gauss('peak2', pos=0.25,ampl=120, fwhm=0.05)
model5 = Background() + Gauss('peak1', pos=0.16, ampl=150, fwhm=0.05)

# %%
models = [model0, model1, model2, model3, model4, model5]
datasets = [df0, df1, df2, df3, df4, df5]
for model, data in zip(models, datasets):
    plt.figure()
    dataset = as_data(data["QL"], data["CNTS"], np.sqrt(data["CNTS"]))
    model.fit(dataset)
    dataset.plot(label = f"H = {int(data['H'][0])} T")
    model.plot(dataset)
    plt.xlabel("(1/3, 1/3, Ql)")
    plt.ylabel("Intensity (a. u.)")
    plt.title("")
    plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
df = pd.read_csv("H_along_ab/300mK/090066.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
model = Background() + Gauss('peak1', pos=1/12, ampl=150, fwhm=0.05) + Gauss('peak2', pos=2/12, ampl=100, fwhm=0.05)+ Gauss('peak3', pos=1/6, ampl=100, fwhm=0.05)
        #+ Gauss('peak4', pos=1/3, ampl=100, fwhm=0.05)
        #+ Gauss('peak5', pos=5/12, ampl=100, fwhm=0.05)
dataset = as_data(df["QL"], df["CNTS"], np.sqrt(df["CNTS"]))
model.fit(dataset)
model.fit(dataset)
dataset.plot(label = f"H = {df['H'][0]} T")
model.plot(dataset)
plt.xlabel("(1/3, 1/3, Ql)")
plt.ylabel("Intensity (a. u.)")
plt.title("")
plt.show()
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Sans Serif, Arial, Helvetica, Lucida Grande, Bitstream Vera Sans
# ...

# %%
df0 = pd.read_csv("H_along_ab/1200mK/090117.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df1 = pd.read_csv("H_along_ab/1200mK/090125.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
df2 = pd.read_csv("H_along_ab/1200mK/090135.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)

plt.figure()
plt.plot(df0["QL"], df0["CNTS"], "b-o", label = f"H = {df0['H'][0]} T")
plt.plot(df1["QL"], df1["CNTS"], "r-o", label = f"H = {df1['H'][0]} T")
plt.plot(df2["QL"], df2["CNTS"], "k-o", label = f"H = {df2['H'][0]} T")

plt.xlabel("(1/3, 1/3, Ql)")
plt.ylabel("Intensity (a. u.)")
plt.legend()
plt.savefig("1200mK_all_phases_ab.png")
plt.show()

# %%
df = pd.read_csv("H_along_ab/1200mK/090117.txt",  names=["QH", "QK", "QL", "CNTS", "1", "2", "3", "4", "5", "6", "T", "H", "7"], sep=",", dtype=np.float64)
model = Background() + Gauss('peak1', pos=0.147, ampl=150, fwhm=0.05)

dataset = as_data(df["QL"], df["CNTS"], np.sqrt(df["CNTS"]))
result = model.fit(dataset)
dataset.plot(label = f"H = {df['H'][0]} T")
model.plot(dataset)
result.printout()
plt.xlabel("(1/3, 1/3, Ql)")
plt.ylabel("Intensity (a. u.)")
plt.savefig("1200mK_ab_fit_AFM2.png")
plt.title("")
plt.show()
# Out:
# Fit results for data
# --------------------------------------------------------------------------------
# bkgd            =      44.45 +/-    0.93534
# peak1_pos       =    0.14048 +/- 0.00082005
# peak1_ampl      =     40.992 +/-     7.5629
# peak1_fwhm      =  0.0091841 +/-  0.0018195
# chi^2/NDF       =      1.317
# ...
